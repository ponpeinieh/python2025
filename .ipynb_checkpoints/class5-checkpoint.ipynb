# %%
def divide(a,b):
    return a/b

a = int(input('請輸入第一個數字:'))
b = int(input('請輸入第二個數字:'))
print(divide(a,b))
print('完成')
# Out:
# 請輸入第一個數字: 10
# 請輸入第二個數字: 0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[5], line 6
#       4 a = int(input('請輸入第一個數字:'))
#       5 b = int(input('請輸入第二個數字:'))
# ----> 6 print(divide(a,b))
#       7 print('完成')
#
# Cell In[5], line 2, in divide(a, b)
#       1 def divide(a,b):
# ----> 2     return a/b
#
# ZeroDivisionError: division by zero

# %%
a = int(input('請輸入一個整數:'))
import math
print(f'{a} 的平方根: {math.sqrt(a)}')
# Out:
# 請輸入一個整數: -100
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 3
#       1 a = int(input('請輸入一個整數:'))
#       2 import math
# ----> 3 print(f'{a} 的平方根: {math.sqrt(a)}')
#
# ValueError: math domain error

# %%
def divide(a,b):
    try:
        return a/b
    except:
        print('發生不預期的錯誤!')
    return None

a = int(input('請輸入第一個數字:'))
b = int(input('請輸入第二個數字:'))
print(divide(a,b))
print('完成')
# Out:
# 請輸入第一個數字: 10
# 請輸入第二個數字: 0
# 發生不預期的錯誤!
# None
# 完成

# %%
def divide(a,b):
    try:
        return a/b
    except ZeroDivisionError:
        # print('發生不預期的錯誤!')
        print('除數不能為0!')
    return None
while True:
    try:
        a = int(input('請輸入第一個數字:'))
        b = int(input('請輸入第二個數字:'))
        break
    except ValueError:
        print('輸入的數值錯誤!請重新輸入!')
print(divide(a,b))
print('完成')
# Out:
# 請輸入第一個數字: a
# 輸入的數值錯誤!請重新輸入!
# 請輸入第一個數字: b
# 輸入的數值錯誤!請重新輸入!
# 請輸入第一個數字: 10
# 請輸入第二個數字: 3
# 3.3333333333333335
# 完成

# %%
def divide(a,b):
    return a/b
    
while True:
    try:
        a = int(input('請輸入第一個數字:'))
        b = int(input('請輸入第二個數字:'))
        break
    except ValueError:
        print('輸入的數值錯誤!請重新輸入!')
try:
    print(divide(a,b))
except ZeroDivisionError:
    print('除數為0!')
print('完成')
# Out:
# 請輸入第一個數字: 10
# 請輸入第二個數字: 0
# 除數為0!
# 完成

# %%
def divide(a,b):
    return a/b
    
while True:
    try:
        a = int(input('請輸入第一個數字:'))
        b = int(input('請輸入第二個數字:'))
        break
    except ValueError:
        print('輸入的數值錯誤!請重新輸入!')
print(divide(a,b))
print('完成')
# Out:
# 請輸入第一個數字: 10
# 請輸入第二個數字: 0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[13], line 11
#       9     except ValueError:
#      10         print('輸入的數值錯誤!請重新輸入!')
# ---> 11 print(divide(a,b))
#      12 print('完成')
#
# Cell In[13], line 2, in divide(a, b)
#       1 def divide(a,b):
# ----> 2     return a/b
#
# ZeroDivisionError: division by zero

# %%
def divide(a,b):
    return a/b
    
while True:
    try:
        a = int(input('請輸入第一個數字:'))
        b = int(input('請輸入第二個數字:'))
        print(divide(a,b))
        break
    except ValueError:
        print('輸入的數值錯誤!請重新輸入!')
    except ZeroDivisionError:
        print('除以0的錯誤!')

print('完成')
# Out:
# 請輸入第一個數字: a
# 輸入的數值錯誤!請重新輸入!
# 請輸入第一個數字: 10
# 請輸入第二個數字: a
# 輸入的數值錯誤!請重新輸入!
# 請輸入第一個數字: 10
# 請輸入第二個數字: 3
# 3.3333333333333335
# 完成
