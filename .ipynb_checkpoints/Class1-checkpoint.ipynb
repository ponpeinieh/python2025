# %%
100*3

# %%
100/3

# %%
100//3

# %%
# 餘數
100 % 3

# %%
# 指數
3**4

# %%
# 使用math模組
import math
math.sin(30*(2*math.pi)/360)

# %%
math.sqrt(100)

# %%
# ceil(), floor()
print(math.ceil(3.7))
print(math.floor(3.7))

# %%
math.log(100,10)

# %%
# python variable
age = 20
weight = 65.5
name = "John"
title = 'Mr'
# 布林值(Boolean)
passed = True
failed = False

# %%
a = 100
print(a)

# %%
a = 'hello'
print(a)
